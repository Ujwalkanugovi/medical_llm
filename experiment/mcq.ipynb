# %%
import os 
import json
import pandas as pd 
import traceback

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import ChatOpenAI

# %%
KEY = os.getenv("OPENAI_API_KEY")

# %%
print(KEY)
# Out:
# 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

# %%
llm = ChatOpenAI(openai_api_key= KEY, model_name = "gpt-3.5-turbo",temperature =0.5)
